# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **JONATHAN SANTOYO VAZQUEZ**
#
# I want to become a data scientist

# %% [markdown]
# *I am very interested in data science because there are many application areas for this branch, and it is also very interesting to find insights in data.*

# %% [markdown]
# ### The following code for a simple mathematical operation to add two numbers.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# |   |   |   |   |   |
# |---|---|---|---|---|
# |   |   |   |   |   |
# |   |   |   |   |   |
# |   |   |   |   |   |
#
# ---
#
# * 1
# * 2
# * 3
#
# ---
#
# 1. item 1
# 2. item 2
# 3. item 3
#
# ---
#
# ``` python
# print("Hello World!")
# ```
#
# ---
#
# > Somewhere, something incredible is waiting to be known
#
# ---
#
# ~~strike-through text~~
#
# ---
#
# [Link to https://example.com](https://example.com)
#
# ---
#
# ![random image](https://picsum.photos/200/300)
